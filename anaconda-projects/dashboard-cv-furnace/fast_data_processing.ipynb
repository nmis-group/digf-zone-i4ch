# %%
# Import required packages

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import glob
import os
import time
from pathlib import Path
import functools as ft
import data_processing_methods as dpm
import multiprocessing as mp
from multiprocessing import  Pool

# %%
# Read the csv file with sensors in use
sensors_TRUE_colnames=pd.read_csv('/raid/nmis-ddm/nmis-furnace/Sensors/sensors_TRUE.csv', header = None)
sensors_TRUE_colnames.columns = ["Sensors", "Condition"]

# Collect the sensor with True condition.
list_true = sensors_TRUE_colnames[sensors_TRUE_colnames['Condition']==True]['Sensors'].tolist()

# %%
# Function for selecting required time range and interplotaing them for the required sampling frequency
def index_todatetime(df):    
    # Define the start and end date
    start_date = '2022-09-06'
    end_date = '2022-10-14'
    
    #create empty df from start date and end date with the required sampling frequency
    sampling_frequency='10S'
    expected_dt_df = pd.DataFrame({'Date' : pd.date_range(start_date, end_date, freq=sampling_frequency)})
    expected_date_time = pd.to_datetime(expected_dt_df['Date'], yearfirst=True)
    
    # Isolate required date range
    date_time = pd.to_datetime(df['Date'], format='%d/%m/%Y %H:%M:%S', errors='coerce')
   
    
    data_raw = df['Value']
    data_raw, date_time = dpm.isolate_time_period(data_raw, date_time,
                                               start_date, end_date)
    
    # Convert to seconds and interpolate
    x_ts, ff_ts = dpm.convert_to_seconds(date_time, expected_date_time)
    data_raw = dpm.interpolate(data_raw, x_ts, ff_ts)
    
    # Save the new dataframes
    df_new = pd.DataFrame({})
    df_new.index = expected_date_time
    df_new['Value'] = data_raw
           
    return df_new

# In windows you need to insert a guard in the main module to avoid creating 
# subprocesses recursively
if __name__ == '__main__':
    # Create dataframesfor a dictionary of all sensor data.
    # Dictionary formate : { sensor's name: {sensor's data in dataframe formate}
    start = time.time()

    print('Function start at: '+time.ctime(start))

    # Set the path to read the raw data
    data_files = '/raid/nmis-ddm/nmis-furnace/Raw_furnace_data'
    file_path = Path("/raid/nmis-ddm/nmis-furnace/Raw_furnace_data")
    
    d = {}
    d_new = {}
    
    def create_dataframes(name):
    
        loop_start=time.time()
        d[name] = pd.DataFrame()
        d[name]= pd.concat([pd.read_csv(j,sep=';',on_bad_lines='skip') for  j in file_path.glob(str(name)+'*.csv')], ignore_index= True)
        d[name].drop('Name', axis=1, inplace=True)
        d[name] = d[name].sort_values(by=['Date'])
        d_new [name] = pd.DataFrame()
        d_new [name] = index_todatetime(d[name])
        d_new [name].rename(columns={'Value': str(name)}, inplace=True)
    
        return d_new [name]
    
    # multiprocessing        
    pool = mp.Pool(processes = (mp.cpu_count() - 1))
    results = pool.map(create_dataframes, list_true)
    pool.close()
    pool.join()

    end = time.time()
    print('Total Time: ' + str(round((end - start),2)) + ' Second')
# Out:
# Function start at: Wed Dec 14 09:37:17 2022
# /home/sjayasinghe/digf-zone-i4ch/anaconda-projects/dashboard-cv-furnace/envs/default/lib/python3.8/site-packages/scipy/interpolate/_interpolate.py:653: RuntimeWarning: divide by zero encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# Total Time: 27.16 Second

# %%
results[1]
# Out:
#                      AIR_0123_945_05_TE
# Date
# 2022-09-06 00:00:00               24.50
# 2022-09-06 00:00:10               24.50
# 2022-09-06 00:00:20               24.50
# 2022-09-06 00:00:30               24.50
# 2022-09-06 00:00:40               24.50
# ...                                 ...
# 2022-10-13 23:59:20               22.03
# 2022-10-13 23:59:30               22.05
# 2022-10-13 23:59:40               22.01
# 2022-10-13 23:59:50               22.02
# 2022-10-14 00:00:00               22.00
#
# [328321 rows x 1 columns]

# %%
start = time.time()
import functools as ft
df_merged = results[1].copy()

for i in range(2, len(results)):
    df_merged = df_merged.merge(results[i],on=['Date'],how='left')
end = time.time()
print(end - start)

df_merged
# Out:
# 2.214247703552246
#                      AIR_0123_945_05_TE  AIR_PID_COMBUSTION_AIR_PV  \
# Date
# 2022-09-06 00:00:00               24.50                   1.551648
# 2022-09-06 00:00:10               24.50                   1.627604
# 2022-09-06 00:00:20               24.50                   1.555266
# 2022-09-06 00:00:30               24.50                   1.576967
# 2022-09-06 00:00:40               24.50                   1.627604
# ...                                 ...                        ...
# 2022-10-13 23:59:20               22.03                   0.940393
# 2022-10-13 23:59:30               22.05                   0.998264
# 2022-10-13 23:59:40               22.01                   1.012731
# 2022-10-13 23:59:50               22.02                   0.951244
# 2022-10-14 00:00:00               22.00                   1.110386
#
#                      AIR_PID_COMBUSTION_AIR_SP  AIR_PID_COMBUSTION_AIR_OUT  \
# Date
# 2022-09-06 00:00:00                      100.0                       100.0
# 2022-09-06 00:00:10                      100.0                       100.0
# 2022-09-06 00:00:20                      100.0                       100.0
# 2022-09-06 00:00:30                      100.0                       100.0
# 2022-09-06 00:00:40                      100.0                       100.0
# ...                                        ...                         ...
# 2022-10-13 23:59:20                      100.0                       100.0
# 2022-10-13 23:59:30                      100.0                       100.0
# 2022-10-13 23:59:40                      100.0                       100.0
# 2022-10-13 23:59:50                      100.0                       100.0
# 2022-10-14 00:00:00                      100.0                       100.0
#
#                      AIR_DRIVE_AIR_SPEED  AIR_0123_945_03_PT  \
# Date
# 2022-09-06 00:00:00                  0.0            1.519097
# 2022-09-06 00:00:10                  0.0            1.627604
# 2022-09-06 00:00:20                  0.0            1.562500
# 2022-09-06 00:00:30                  0.0            1.584202
# 2022-09-06 00:00:40                  0.0            1.627604
# ...                                  ...                 ...
# 2022-10-13 23:59:20                  0.0            0.940393
# 2022-10-13 23:59:30                  0.0            0.940393
# 2022-10-13 23:59:40                  0.0            1.012731
# 2022-10-13 23:59:50                  0.0            0.976562
# 2022-10-14 00:00:00                  0.0            1.099536
#
#                      FURNACE_PID_FURNACE_PRESSURE_SP  \
# Date
# 2022-09-06 00:00:00                             20.0
# 2022-09-06 00:00:10                             20.0
# 2022-09-06 00:00:20                             20.0
# 2022-09-06 00:00:30                             20.0
# 2022-09-06 00:00:40                             20.0
# ...                                              ...
# 2022-10-13 23:59:20                             20.0
# 2022-10-13 23:59:30                             20.0
# 2022-10-13 23:59:40                             20.0
# 2022-10-13 23:59:50                             20.0
# 2022-10-14 00:00:00                             20.0
#
#                      FURNACE_PID_FURNACE_PRESSURE_OUT  FURNACE_0126_341_04_O2  \
# Date
# 2022-09-06 00:00:00                             100.0                     0.0
# 2022-09-06 00:00:10                             100.0                     0.0
# 2022-09-06 00:00:20                             100.0                     0.0
# 2022-09-06 00:00:30                             100.0                     0.0
# 2022-09-06 00:00:40                             100.0                     0.0
# ...                                               ...                     ...
# 2022-10-13 23:59:20                              96.0                    21.0
# 2022-10-13 23:59:30                              96.0                    21.0
# 2022-10-13 23:59:40                              96.0                    21.0
# 2022-10-13 23:59:50                              96.0                    21.0
# 2022-10-14 00:00:00                              96.0                    21.0
#
#                      FURNACE_0126_341_02_PDT  ...  ROOF_0104_300_01_TC  \
# Date                                          ...
# 2022-09-06 00:00:00                -1.064453  ...            25.000000
# 2022-09-06 00:00:10                -1.080006  ...            25.080020
# 2022-09-06 00:00:20                -1.078378  ...            25.000000
# 2022-09-06 00:00:30                -1.076027  ...            25.000000
# 2022-09-06 00:00:40                -1.090857  ...            25.000000
# ...                                      ...  ...                  ...
# 2022-10-13 23:59:20                -8.362631  ...            72.899990
# 2022-10-13 23:59:30                -8.360460  ...            73.000000
# 2022-10-13 23:59:40                -8.362268  ...            73.100010
# 2022-10-13 23:59:50                -8.364077  ...            73.000000
# 2022-10-14 00:00:00                -8.361062  ...            72.966663
#
#                      ROOF_0104_300_02_TC  ROOF_0104_300_03_TC  \
# Date
# 2022-09-06 00:00:00             25.70001             24.70001
# 2022-09-06 00:00:10             25.80002             24.60001
# 2022-09-06 00:00:20             25.80002             24.60001
# 2022-09-06 00:00:30             25.70001             24.60001
# 2022-09-06 00:00:40             25.70001             24.60001
# ...                                  ...                  ...
# 2022-10-13 23:59:20            196.20000            323.30000
# 2022-10-13 23:59:30            196.20000            323.40000
# 2022-10-13 23:59:40            196.30000            323.40000
# 2022-10-13 23:59:50            196.30000            323.30000
# 2022-10-14 00:00:00            196.30000            323.30000
#
#                      ROOF_0104_300_04_TC  ROOF_0104_300_05_TC  \
# Date
# 2022-09-06 00:00:00            24.700020                  0.0
# 2022-09-06 00:00:10            24.500000                  0.0
# 2022-09-06 00:00:20            24.500000                  0.0
# 2022-09-06 00:00:30            24.500000                  0.0
# 2022-09-06 00:00:40            24.500000                  0.0
# ...                                  ...                  ...
# 2022-10-13 23:59:20           434.300000                  0.0
# 2022-10-13 23:59:30           434.400000                  0.0
# 2022-10-13 23:59:40           434.400000                  0.0
# 2022-10-13 23:59:50           434.300000                  0.0
# 2022-10-14 00:00:00           434.266667                  0.0
#
#                      ROOF_0104_300_06_TC  ROOF_0104_300_07_TC  \
# Date
# 2022-09-06 00:00:00            25.000000             26.39999
# 2022-09-06 00:00:10            25.000000             26.39999
# 2022-09-06 00:00:20            25.000000             26.50000
# 2022-09-06 00:00:30            25.000000             26.50000
# 2022-09-06 00:00:40            25.050005             26.50000
# ...                                  ...                  ...
# 2022-10-13 23:59:20           501.300000             26.50000
# 2022-10-13 23:59:30           501.300000             26.50000
# 2022-10-13 23:59:40           501.300000             26.30002
# 2022-10-13 23:59:50           501.200000             26.38000
# 2022-10-14 00:00:00           501.200000             26.39999
#
#                      ROOF_0104_300_08_TC  ROOF_0104_300_09_TC  \
# Date
# 2022-09-06 00:00:00             24.89999             25.89999
# 2022-09-06 00:00:10             24.89999             25.80002
# 2022-09-06 00:00:20             25.00000             25.89999
# 2022-09-06 00:00:30             25.00000             25.80002
# 2022-09-06 00:00:40             25.00000             25.80002
# ...                                  ...                  ...
# 2022-10-13 23:59:20              0.00000             23.30002
# 2022-10-13 23:59:30              0.00000             23.20001
# 2022-10-13 23:59:40              0.00000             23.20001
# 2022-10-13 23:59:50              0.00000             23.30002
# 2022-10-14 00:00:00              0.00000             23.20001
#
#                      ROOF_0104_300_10_TC
# Date
# 2022-09-06 00:00:00            25.399990
# 2022-09-06 00:00:10            25.399990
# 2022-09-06 00:00:20            25.489990
# 2022-09-06 00:00:30            25.399990
# 2022-09-06 00:00:40            25.449995
# ...                                  ...
# 2022-10-13 23:59:20           452.100000
# 2022-10-13 23:59:30           452.000000
# 2022-10-13 23:59:40           451.900000
# 2022-10-13 23:59:50           452.100000
# 2022-10-14 00:00:00           452.100000
#
# [328321 rows x 34 columns]
